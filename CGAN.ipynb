# %% [markdown]
# # Reference
# - https://github.com/eriklindernoren/PyTorch-GAN

# %%
import torchvision.datasets as datasets
import os
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torchvision import utils
import matplotlib.pyplot as plt
import numpy as np
import torch.nn as nn
import torch
import torch.nn.functional as F
import time
from torchvision.transforms.functional import to_pil_image
# %matplotlib inline

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # 데이터셋 불러오기

# %%
# 데이터 경로 지정
path2data = './FashionMNIST'
os.makedirs(path2data, exist_ok=True)

# %%
# Transformation 정의
train_transform = transforms.Compose([
                        transforms.ToTensor(),
                        transforms.Normalize([0.5],[0.5]),
])

# %%
# MNIST dataset 불러오기
train_ds = datasets.FashionMNIST(path2data, train=True, transform=train_transform, download=True)

# %%
# 샘플 이미지 확인하기
img, label = train_ds.data, train_ds.targets

# 차원 추가
if len(img.shape) == 3:
    img = img.unsqueeze(1) # B*C*H*W

# 그리드 생성
img_grid = utils.make_grid(img[:40], nrow=8, padding=2)

def show(img):
    npimg = img.numpy()
    npimg_tr = npimg.transpose((1,2,0)) # [C,H,W] -> [H,W,C]
    plt.imshow(npimg_tr, interpolation='nearest')

show(img_grid)

# %%
# 데이터 로더 생성
train_dl = DataLoader(train_ds, batch_size=64, shuffle=True, num_workers=16)

# %% [markdown]
# # 모델 구축하기

# %%
# 파라미터 설정
params = {'num_classes':10,
          'nz':100,
          'input_size':(1,28,28)}

# %%
# Generator: 가짜 이미지를 생성합니다.
# noise와 label을 결합하여 학습합니다..

class Generator(nn.Module):
    def __init__(self, params):
        super().__init__()
        self.num_classes = params['num_classes'] # 클래스 수, 10
        self.nz = params['nz'] # 노이즈 수, 100
        self.input_size = params['input_size'] # (1,28,28)

        # noise와 label을 결합할 용도인 label embedding matrix를 생성합니다.
        self.label_emb = nn.Embedding(self.num_classes, self.num_classes)

        self.gen = nn.Sequential(
            nn.Linear(self.nz + self.num_classes, 128),
            nn.LeakyReLU(0.2),
            nn.Linear(128,256),
            nn.BatchNorm1d(256),
            nn.LeakyReLU(0.2),
            nn.Linear(256,512),
            nn.BatchNorm1d(512),
            nn.LeakyReLU(0.2),
            nn.Linear(512,1024),
            nn.BatchNorm1d(1024),
            nn.LeakyReLU(0.2),
            nn.Linear(1024,int(np.prod(self.input_size))),
            nn.Tanh()
        )

    def forward(self, noise, labels):
        # noise와 label 결합
        gen_input = torch.cat((self.label_emb(labels),noise),-1)
        x = self.gen(gen_input)
        x = x.view(x.size(0), *self.input_size)
        return x

# check
x = torch.randn(16,100,device=device) # 노이즈
label = torch.randint(0,10,(16,),device=device) # 레이블
model_gen = Generator(params).to(device)
out_gen = model_gen(x,label) # 가짜 이미지 생성
print(out_gen.shape)
# Out:
# torch.Size([16, 1, 28, 28])

# %%
# Discriminator: 가짜 이미지와 진짜 이미지를 식별합니다.
class Discriminator(nn.Module):
    def __init__(self,params):
        super().__init__()
        self.input_size = params['input_size']
        self.num_classes = params['num_classes']

        self.label_embedding = nn.Embedding(self.num_classes, self.num_classes)

        self.dis = nn.Sequential(
            nn.Linear(self.num_classes+int(np.prod(self.input_size)),1024),
            nn.LeakyReLU(0.2),
            nn.Linear(1024,512),
            nn.Dropout(0.4),
            nn.LeakyReLU(0.2),
            nn.Linear(512,256),
            nn.Dropout(0.4),
            nn.LeakyReLU(0.2),
            nn.Linear(256,1),
            nn.Sigmoid()
        )

    def forward(self, img, labels):
        # 이미지와 label 결합
        dis_input = torch.cat((img.view(img.size(0),-1),self.label_embedding(labels)),-1)

        x = self.dis(dis_input)
        return x

# check
x = torch.randn(16,1,28,28,device=device)
label = torch.randint(0,10,(16,), device=device)
model_dis = Discriminator(params).to(device)
out_dis = model_dis(x,label)
print(out_dis.shape)
# Out:
# torch.Size([16, 1])

# %%
# 가중치 초기화
def initialize_weights(model):
    classname = model.__class__.__name__
    # fc layer
    if classname.find('Linear') != -1:
        nn.init.normal_(model.weight.data, 0.0, 0.02)
        nn.init.constant_(model.bias.data, 0)
    # batchnorm
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(model.weight.data, 1.0, 0.02)
        nn.init.constant_(model.bias.data, 0)

# 가중치 초기화 적용
model_gen.apply(initialize_weights);
model_dis.apply(initialize_weights);

# %% [markdown]
# # 학습하기

# %%
# 손실 함수
loss_func = nn.BCELoss()

from torch import optim

lr = 2e-4
beta1 = 0.5
beta2 = 0.999

# optimization
opt_dis = optim.Adam(model_dis.parameters(), lr=lr, betas=(beta1,beta2))
opt_gen = optim.Adam(model_gen.parameters(), lr=lr, betas=(beta1,beta2))

# %%
nz = params['nz']
num_epochs = 150

loss_history={'gen':[],
              'dis':[]}

# %%
# 학습
batch_count = 0
start_time = time.time()
model_dis.train()
model_gen.train()

for epoch in range(num_epochs):
    for xb, yb in train_dl:
        ba_si = xb.shape[0]

        xb = xb.to(device)
        yb = yb.to(device)
        yb_real = torch.Tensor(ba_si,1).fill_(1.0).to(device) # real_label
        yb_fake = torch.Tensor(ba_si,1).fill_(0.0).to(device) # fake_label

        # Genetator
        model_gen.zero_grad()
        noise = torch.randn(ba_si,100).to(device) # 노이즈 생성
        gen_label = torch.randint(0,10,(ba_si,)).to(device) # label 생성

        # 가짜 이미지 생성
        out_gen = model_gen(noise, gen_label)

        # 가짜 이미지 판별
        out_dis = model_dis(out_gen, gen_label)

        loss_gen = loss_func(out_dis, yb_real)
        loss_gen.backward()
        opt_gen.step()

        # Discriminator
        model_dis.zero_grad()
        
        # 진짜 이미지 판별
        out_dis = model_dis(xb, yb)
        loss_real = loss_func(out_dis, yb_real)

        # 가짜 이미지 판별
        out_dis = model_dis(out_gen.detach(),gen_label)
        loss_fake = loss_func(out_dis,yb_fake)

        loss_dis = (loss_real + loss_fake) / 2
        loss_dis.backward()
        opt_dis.step()

        loss_history['gen'].append(loss_gen.item())
        loss_history['dis'].append(loss_dis.item())

        batch_count += 1
        if batch_count % 1000 == 0:
            print('Epoch: %.0f, G_Loss: %.6f, D_Loss: %.6f, time: %.2f min' %(epoch, loss_gen.item(), loss_dis.item(), (time.time()-start_time)/60))
# Out:
# Epoch: 1, G_Loss: 1.687613, D_Loss: 0.588655, time: 0.32 min
# Epoch: 2, G_Loss: 1.641109, D_Loss: 0.540019, time: 0.62 min
# Epoch: 3, G_Loss: 0.857269, D_Loss: 0.571818, time: 0.93 min
# Epoch: 4, G_Loss: 1.582847, D_Loss: 0.664806, time: 1.23 min
# Epoch: 5, G_Loss: 1.255850, D_Loss: 0.513578, time: 1.54 min
# Epoch: 6, G_Loss: 1.074444, D_Loss: 0.431331, time: 1.84 min
# Epoch: 7, G_Loss: 0.867828, D_Loss: 0.576081, time: 2.16 min
# Epoch: 8, G_Loss: 0.809636, D_Loss: 0.497516, time: 2.47 min
# Epoch: 9, G_Loss: 1.089272, D_Loss: 0.622043, time: 2.77 min
# Epoch: 10, G_Loss: 0.828475, D_Loss: 0.630868, time: 3.07 min
# Epoch: 11, G_Loss: 0.695108, D_Loss: 0.650370, time: 3.37 min
# Epoch: 12, G_Loss: 0.781218, D_Loss: 0.610997, time: 3.67 min
# Epoch: 13, G_Loss: 0.772416, D_Loss: 0.607659, time: 3.95 min
# Epoch: 14, G_Loss: 0.789228, D_Loss: 0.612220, time: 4.24 min
# Epoch: 15, G_Loss: 0.781115, D_Loss: 0.600706, time: 4.55 min
# Epoch: 17, G_Loss: 1.294541, D_Loss: 0.773305, time: 4.87 min
# Epoch: 18, G_Loss: 0.978510, D_Loss: 0.608382, time: 5.15 min
# Epoch: 19, G_Loss: 0.941318, D_Loss: 0.579821, time: 5.46 min
# Epoch: 20, G_Loss: 0.901760, D_Loss: 0.644284, time: 5.76 min
# Epoch: 21, G_Loss: 0.737247, D_Loss: 0.690844, time: 6.04 min
# Epoch: 22, G_Loss: 1.164398, D_Loss: 0.620867, time: 6.34 min
# Epoch: 23, G_Loss: 0.935679, D_Loss: 0.647182, time: 6.65 min
# Epoch: 24, G_Loss: 0.700368, D_Loss: 0.634798, time: 6.95 min
# Epoch: 25, G_Loss: 0.855631, D_Loss: 0.662709, time: 7.24 min
# Epoch: 26, G_Loss: 0.843100, D_Loss: 0.562638, time: 7.52 min
# Epoch: 27, G_Loss: 0.933136, D_Loss: 0.609757, time: 7.81 min
# Epoch: 28, G_Loss: 0.833128, D_Loss: 0.631848, time: 8.09 min
